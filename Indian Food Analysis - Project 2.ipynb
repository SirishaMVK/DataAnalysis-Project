# %% [markdown]
# # Indian Food Data Analysis

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Load the dataset

# %%
df=pd.read_csv(r"Indian_food.csv")
df
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %% [markdown]
# ### Display the list of columns

# %%
df.columns
# Out:
# Index(['name', 'ingredients', 'diet', 'prep_time', 'cook_time',
#        'flavor_profile', 'course', 'state', 'region'],
#       dtype='object')

# %% [markdown]
# ### Shape of the dataset

# %%
df.shape
# Out:
# (255, 9)

# %% [markdown]
# ### No of columns and no of rows

# %%
No_of_columns=len(df.columns)
No_of_columns
No_of_rows=len(df.index)
print(No_of_columns)
print(No_of_rows)
# Out:
# 9
# 255

# %% [markdown]
# ### First 10 rows of the dataset

# %%
df.head(10)
# Out:
#              name                                        ingredients  \
# 0      Balu shahi                    Maida flour, yogurt, oil, sugar
# 1          Boondi                            Gram flour, ghee, sugar
# 2  Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3          Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4     Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# 5          Imarti                          Sugar syrup, lentil flour
# 6          Jalebi  Maida, corn flour, baking soda, vinegar, curd,...
# 7      Kaju katli                     Cashews, ghee, cardamom, sugar
# 8        Kalakand                        Milk, cottage cheese, sugar
# 9           Kheer                    Milk, rice, sugar, dried fruits
#
#          diet  prep_time  cook_time flavor_profile   course          state  \
# 0  vegetarian         45         25          sweet  dessert    West Bengal
# ...

# %% [markdown]
# ### Last 10 rows of the dataset

# %%
df.tail(10)
# Out:
#                   name                                        ingredients  \
# 245         Pani Pitha  Tea leaves, white sesame seeds, dry coconut, s...
# 246             Payokh  Basmati rice, rose water, sugar, clarified but...
# 247  Prawn malai curry      Coconut milk, prawns, garlic, turmeric, sugar
# 248           Red Rice  Red pepper, red onion, butter, watercress, oli...
# 249             Shukto  Green beans, bitter gourd, ridge gourd, banana...
# 250          Til Pitha            Glutinous rice, black sesame seeds, gur
# 251            Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252             Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253          Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254             Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#                diet  prep_time  cook_time flavor_profile       course  \
# 245      vegetarian         10         20             -1  main course
# ...

# %% [markdown]
# ### Datatype of the df

# %%
df.dtypes
# Out:
# name              object
# ingredients       object
# diet              object
# prep_time          int64
# cook_time          int64
# flavor_profile    object
# course            object
# state             object
# region            object
# dtype: object

# %% [markdown]
# ### check for null values

# %%
df.isnull().any()
# Out:
# name              False
# ingredients       False
# diet              False
# prep_time         False
# cook_time         False
# flavor_profile    False
# course            False
# state             False
# region             True
# dtype: bool

# %% [markdown]
# ### Count the empty value in each column

# %%
df.isnull().sum()
# Out:
# name              0
# ingredients       0
# diet              0
# prep_time         0
# cook_time         0
# flavor_profile    0
# course            0
# state             0
# region            1
# dtype: int64

# %% [markdown]
# ### Replace -1 with Null value

# %%
df.replace({-1:np.NaN,
           "-1":np.NaN}, inplace=True)
df
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %% [markdown]
# ### Check for duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Check the diets available

# %%
diet_=df["diet"].value_counts()
diet_
# Out:
# vegetarian        226
# non vegetarian     29
# Name: diet, dtype: int64

# %%
sns.barplot(diet_.index,diet_.values)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %% [markdown]
# ### Filter the 'flavor_profile' column for the value "sweet" and 'course' columns value equal to 'desert'

# %%
filter1 = df[df['flavor_profile']=='sweet']
filter2 = filter1[filter1['course']=='dessert']
filter2
# Out:
#                name                                        ingredients  \
# 0        Balu shahi                    Maida flour, yogurt, oil, sugar
# 1            Boondi                            Gram flour, ghee, sugar
# 2    Gajar ka halwa       Carrots, milk, sugar, ghee, cashews, raisins
# 3            Ghevar  Flour, ghee, kewra, milk, clarified butter, su...
# 4       Gulab jamun  Milk powder, plain flour, baking powder, ghee,...
# ..              ...                                                ...
# 250       Til Pitha            Glutinous rice, black sesame seeds, gur
# 251         Bebinca  Coconut milk, egg yolks, clarified butter, all...
# 252          Shufta  Cottage cheese, dry dates, dried rose petals, ...
# 253       Mawa Bati  Milk powder, dry fruits, arrowroot powder, all...
# 254          Pinaca  Brown rice, fennel seeds, grated coconut, blac...
#
#            diet  prep_time  cook_time flavor_profile   course  \
# ...

# %% [markdown]
# ### Display only the following columns with values: cook_time,name and
# sort 'cook_time' column in ascending order

# %%
cook_time_sort=df[["name","cook_time"]]
cook_time_sort=cook_time_sort.sort_values(["cook_time"],ascending=True)
cook_time_sort
# Out:
#               name  cook_time
# 109      Pani puri        2.0
# 111          Papad        5.0
# 11           Lassi        5.0
# 147        Papadum        5.0
# 212  Lilva Kachori        6.0
# ..             ...        ...
# 244        Pakhala        NaN
# 246         Payokh        NaN
# 248       Red Rice        NaN
# 252         Shufta        NaN
# 254         Pinaca        NaN
#
# [255 rows x 2 columns]

# %% [markdown]
# ### Visualise the plot using matplotlib or seaborn with the following columns:
# x= cook_time('cook_time' column values should be in descending order)
# y= name

# %%
cook_time_sort=cook_time_sort.sort_values(["cook_time"],ascending=True)
x=cook_time_sort["name"]
y=cook_time_sort["cook_time"]
plt.plot(x,y)

# %% [markdown]
# ### Display countplot in seaborn for flavor_profile column

# %%
sns.countplot("flavor_profile",data=df)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='flavor_profile', ylabel='count'>
